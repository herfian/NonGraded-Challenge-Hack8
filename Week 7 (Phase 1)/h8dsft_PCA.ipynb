# %% [markdown]
# ##**NON GRADED CHALLENGE 3**
#
# ##**BY : M RIZKI HERFIAN**
#
# ##**MATERI : PRINCIPAL COMPONENTS ANALYSIS (PCA)**

# %% [markdown]
# **Assignment Instructions :**
# * Source Dataset = https://www.kaggle.com/mlg-ulb/creditcardfraud.
# * Lakukan cleaning dan preprocessing terhadap data yang akan dipakai
# * Buat sebuah model untuk mengurangi dimensi data dengan menggunakan PCA
# * Buatlah visualisasi data dari model PCA yang telah dibuat

# %% [markdown]
# **Assignment Objectives**
#
# Non-Graded Assignment ini dibuat guna mengevaluasi konsep Dimensionality Reduction sebagai berikut:
# * Mampu memahami konsep Dimensionality Reduction dengan PCA
# * Mampu mempersiapkan data untuk digunakan dalam model PCA
# * Mampu mengimplementasikan PCA untuk mengurangi dimensi data

# %% [markdown]
# ##**STEP 1 : IMPORT LIBRARY**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## **STEP 2 : LOAD DATASET**

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Hacktiv8/Phase 1/Non Graded Challenge/creditcard.csv')

# %%
data.shape
# Out:
# (284807, 31)

# %% [markdown]
# ## **STEP 3 : DATA EXPLORATION**

# %%
data.head(10)
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
# 5   2.0 -0.425966  0.960523  1.141109  ...  0.253844  0.081080    3.67      0
# 6   4.0  1.229658  0.141004  0.045371  ...  0.034507  0.005168    4.99      0
# 7   7.0 -0.644269  1.417964  1.074380  ... -1.206921 -1.085339   40.80      0
# 8   7.0 -0.894286  0.286157 -0.113192  ...  0.011747  0.142404   93.20      0
# 9   9.0 -0.338262  1.119593  1.044367  ...  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
data.tail(10)
# Out:
#             Time         V1         V2  ...       V28  Amount  Class
# 284797  172782.0  -0.241923   0.712247  ...  0.081265    5.49      0
# 284798  172782.0   0.219529   0.881246  ...  0.215243   24.05      0
# 284799  172783.0  -1.775135  -0.004235  ...  0.130308   79.99      0
# 284800  172784.0   2.039560  -0.175233  ... -0.075071    2.68      0
# 284801  172785.0   0.120316   0.931005  ...  0.068803    2.69      0
# 284802  172786.0 -11.881118  10.071785  ...  0.823731    0.77      0
# 284803  172787.0  -0.732789  -0.055080  ... -0.053527   24.79      0
# 284804  172788.0   1.919565  -0.301254  ... -0.026561   67.88      0
# 284805  172788.0  -0.240440   0.530483  ...  0.104533   10.00      0
# 284806  172792.0  -0.533413  -0.189733  ...  0.013649  217.00      0
#
# [10 rows x 31 columns]

# %%
data.columns.values
# Out:
# array(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9',
#        'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18',
#        'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'Amount', 'Class'], dtype=object)

# %%
data["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe()
# Out:
#                 Time            V1  ...         Amount          Class
# count  284807.000000  2.848070e+05  ...  284807.000000  284807.000000
# mean    94813.859575  3.919560e-15  ...      88.349619       0.001727
# std     47488.145955  1.958696e+00  ...     250.120109       0.041527
# min         0.000000 -5.640751e+01  ...       0.000000       0.000000
# 25%     54201.500000 -9.203734e-01  ...       5.600000       0.000000
# 50%     84692.000000  1.810880e-02  ...      22.000000       0.000000
# 75%    139320.500000  1.315642e+00  ...      77.165000       0.000000
# max    172792.000000  2.454930e+00  ...   25691.160000       1.000000
#
# [8 rows x 31 columns]

# %%
data.describe().T
# Out:
#            count          mean  ...            75%            max
# Time    284807.0  9.481386e+04  ...  139320.500000  172792.000000
# V1      284807.0  3.919560e-15  ...       1.315642       2.454930
# V2      284807.0  5.688174e-16  ...       0.803724      22.057729
# V3      284807.0 -8.769071e-15  ...       1.027196       9.382558
# V4      284807.0  2.782312e-15  ...       0.743341      16.875344
# V5      284807.0 -1.552563e-15  ...       0.611926      34.801666
# V6      284807.0  2.010663e-15  ...       0.398565      73.301626
# V7      284807.0 -1.694249e-15  ...       0.570436     120.589494
# V8      284807.0 -1.927028e-16  ...       0.327346      20.007208
# V9      284807.0 -3.137024e-15  ...       0.597139      15.594995
# V10     284807.0  1.768627e-15  ...       0.453923      23.745136
# V11     284807.0  9.170318e-16  ...       0.739593      12.018913
# V12     284807.0 -1.810658e-15  ...       0.618238       7.848392
# ...

# %% [markdown]
# ##**STEP 4 : DATA CLEANING**

# %%
dtc = data.copy()

# %%
dtc.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
dtc.isna().sum().any()
# Out:
# False

# %%
dtc.duplicated().any()
# Out:
# True

# %%
dtc.duplicated().sum()
# Out:
# 1081

# %%
dtc[dtc.duplicated()]
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 33          26.0 -0.529912  0.873892  ...  0.023307    6.14      0
# 35          26.0 -0.535388  0.865268  ...  0.025427    1.77      0
# 113         74.0  1.038370  0.127486  ...  0.001192    1.18      0
# 114         74.0  1.038370  0.127486  ...  0.001192    1.18      0
# 115         74.0  1.038370  0.127486  ...  0.001192    1.18      0
# ...          ...       ...       ...  ...       ...     ...    ...
# 282987  171288.0  1.912550 -0.455240  ... -0.036020   11.99      0
# 283483  171627.0 -1.464380  1.368119  ...  0.119251    6.82      0
# 283485  171627.0 -1.457978  1.378203  ...  0.116772   11.93      0
# 284191  172233.0 -2.667936  3.160505  ... -0.222200   55.66      0
# 284193  172233.0 -2.691642  3.123168  ... -0.213020   36.74      0
#
# [1081 rows x 31 columns]

# %%
dtc.loc[dtc.duplicated(keep=False),:]
# Out:
#             Time        V1        V2  ...       V28  Amount  Class
# 32          26.0 -0.529912  0.873892  ...  0.023307    6.14      0
# 33          26.0 -0.529912  0.873892  ...  0.023307    6.14      0
# 34          26.0 -0.535388  0.865268  ...  0.025427    1.77      0
# 35          26.0 -0.535388  0.865268  ...  0.025427    1.77      0
# 112         74.0  1.038370  0.127486  ...  0.001192    1.18      0
# ...          ...       ...       ...  ...       ...     ...    ...
# 283485  171627.0 -1.457978  1.378203  ...  0.116772   11.93      0
# 284190  172233.0 -2.667936  3.160505  ... -0.222200   55.66      0
# 284191  172233.0 -2.667936  3.160505  ... -0.222200   55.66      0
# 284192  172233.0 -2.691642  3.123168  ... -0.213020   36.74      0
# 284193  172233.0 -2.691642  3.123168  ... -0.213020   36.74      0
#
# [1854 rows x 31 columns]

# %%
dtc.drop_duplicates(inplace=True)

# %%
dtc.duplicated().any()
# Out:
# False

# %%
dtc.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## **STEP 5 : EDA VISUALIZATION**

# %%
features = dtc.drop(columns=["Class"]).columns.tolist()
len(features)
# Out:
# 30

# %%
plt.figure(figsize=(20, 40))
for i in range(len(features)):
    plt.subplot(len(features)//3, 3, i + 1)
    sns.histplot(
        x = dtc[features[i]]
    )
    plt.title(f"Skew= {dtc[features[i]].skew()}")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 40))
for i in range(len(features)):
    plt.subplot(len(features)//3, 3, i + 1)
    sns.boxplot(
        x = dtc[features[i]]
    )
plt.tight_layout()
plt.show()

# %%
corr_ = dtc[features + ["Class"]].corr(method = 'pearson')
corr_ = corr_.mask(np.tril(np.ones(corr_.shape)).T.astype(np.bool_)).drop(index=["Time"], columns=["Class"])

plt.figure(figsize = (30, 25))
sns.heatmap(
    corr_,
    annot = True,
    fmt = '.3f',
    cmap = 'Blues_r'
)
plt.title("Correlation between Numerical Features")
plt.yticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.countplot(
    x = dtc["Class"]
)
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), '.0f') + " (" + format(p.get_height()*100/len(dtc), '.1f') + "%)",
        (p.get_x() + p.get_width() / 2., p.get_height()+14500), 
        ha = 'center',
        fontweight = 'semibold',
        size = 16,
        xytext = (0, -20), 
        textcoords = 'offset points',
        color = 'gray'
    )
plt.show()

# %% [markdown]
# ## **STEP 6 : DATA PREPROCESSING**

# %%
dtp = dtc.copy()

# %%
X = dtp.drop(columns=['Class'])
y = dtp["Class"]

# %%
scaler = StandardScaler()
X_trf = scaler.fit_transform(X)

# %% [markdown]
# ## **STEP 7 : PRINCIPAL COMPONENTS ANALYSIS (PCA)**

# %%
pca_explained_ratio = []
pca_explained_ratio_sum = []
for i in range(1, 31):
    pca = PCA(n_components = i, random_state = 77)
    pca.fit_transform(X_trf)
    pca_explained_ratio.append(pca.explained_variance_ratio_)
    pca_explained_ratio_sum.append(pca.explained_variance_ratio_.sum())

# %%
for i in range(1, 31):
    print(i, "-", pca_explained_ratio_sum[i-1])
# Out:
# 1 - 0.0655889405604501
# 2 - 0.12191755553716271
# 3 - 0.15545826634953588
# 4 - 0.1893307828557413
# 5 - 0.22307319356837463
# 6 - 0.2567913164735993
# 7 - 0.2905054937765874
# 8 - 0.3239060094693511
# 9 - 0.3576569448898379
# 10 - 0.39139843314958683
# 11 - 0.4250481839476327
# 12 - 0.45867512227802204
# 13 - 0.49234378335784196
# 14 - 0.525709696692063
# 15 - 0.5595315725760547
# 16 - 0.593082158476957
# 17 - 0.6266211592432133
# 18 - 0.660189027646225
# 19 - 0.6936610403952209
# 20 - 0.7269954349785154
# 21 - 0.7603249362573057
# 22 - 0.7935962368668149
# 23 - 0.8268162075532876
# 24 - 0.8600250408996789
# 25 - 0.8927099628620228
# 26 - 0.925174619473256
# 27 - 0.9571439789385642
# 28 - 0.9880728989692532
# 29 - 0.9986095892716444
# 30 - 1.0

# %%
pca = PCA()
pca.fit(X_trf)
cumsum = np.cumsum(pca.explained_variance_ratio_)
d = np.argmax(cumsum >= 0.95) + 1
d
# Out:
# 27

# %%
X.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
pca.explained_variance_ratio_
# Out:
# array([0.0655915 , 0.05634035, 0.0341207 , 0.03401796, 0.03390283,
#        0.03385678, 0.03372041, 0.03366688, 0.03363185, 0.03361129,
#        0.0336046 , 0.03356929, 0.03352902, 0.03348723, 0.03343523,
#        0.03342327, 0.03341597, 0.03338659, 0.0333493 , 0.03333439,
#        0.0333295 , 0.0332713 , 0.03321997, 0.03320883, 0.03268492,
#        0.03246466, 0.03196936, 0.03092892, 0.01053669, 0.00139041])

# %%
plt.figure(figsize=(15,7))
plt.plot(cumsum)
plt.axvline(np.argmax(cumsum >= 0.95) + 1, linestyle="--", color="m")
plt.text(s = np.argmax(cumsum >= 0.95) + 1, y = 0.9, x = np.argmax(cumsum >= 0.95) + 1.5, fontsize=20)
plt.show()

# %%
pca = PCA(n_components = 2, random_state = 77)
X_trf_2D = pca.fit_transform(X_trf)

# %% [markdown]
# ##**STEP 8 : PCA VISUALIZATION**

# %%
pca_class = pd.DataFrame({
    "PCA1":X_trf_2D[:,0],
    "PCA2":X_trf_2D[:,1],
    "Class":y
})

# %%
plt.figure(figsize=(20, 10))
hue_order = [0, 1]
palette = {1:"#9ACD32", 0:"#B57170"}
ax = sns.scatterplot(
    x = "PCA1", y = "PCA2", hue = "Class",
    hue_order = hue_order, palette = palette,
    data = pca_class.sort_values("Class", key=np.vectorize(hue_order.index)),
    s = 250,
    edgecolor = 'white',
    linestyle="--"
)
L = ax.legend(fontsize = 24, markerscale = 3, edgecolor = 'black', loc="lower right")
L.set_title('CLUSTER', prop = {'size' : 24})
plt.tight_layout()
plt.show()
