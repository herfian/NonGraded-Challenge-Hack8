# %% [markdown]
# ##Non Graded Challenge 5
#
# By : Muhammad Rizki Herfian
#
# Materi Matrix

# %% [markdown]
# ##**STEP 1 : Mengimport library Numpy dan Matplotlib**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##**Problem 1 :**
#
# ![Screenshot_21.png](data:image/png;base64,...)

# %% [markdown]
# ##**Solution 1 :**

# %%
Tensor=np.array([
    [[23,50],[7,12]],
    [[57,67],[99,43]],
    [[75,21],[57,12]],
    [[87,26],[18,84]]
])
Tensor
# Out:
# array([[[23, 50],
#         [ 7, 12]],
#
#        [[57, 67],
#         [99, 43]],
#
#        [[75, 21],
#         [57, 12]],
#
#        [[87, 26],
#         [18, 84]]])

# %% [markdown]
# ##**Problem 2 :**
#
# ![Screenshot_22.png](data:image/png;base64,...)

# %% [markdown]
# ##**Solution 2 :**
#
# Membuat matrix A dan B dengan perintah seperti dibawah ini.

# %%
A=np.array([[23,50,19],
            [7,12,109],
            [57,67,98]])
print(A)
# Out:
# [[ 23  50  19]
#  [  7  12 109]
#  [ 57  67  98]]

# %%
B=np.array([
            [17,22,19]
            ])
print(B)
# Out:
# [[17 22 19]]

# %% [markdown]
# Kemudian penyelesaian membuat operasi perkalian matrix A dengan matrix B

# %%
print(A*B)
# Out:
# [[ 391 1100  361]
#  [ 119  264 2071]
#  [ 969 1474 1862]]

# %%
xy=[ #Konsep Perkalian Matrix
  [23*17+50*22+19*19],
  [7*17+12*22+109*19],
  [57*17+67*22+98*19]
 ]
print(xy)
# Out:
# [[1852], [2454], [4305]]

# %%
kali = B@A
kali
# Out:
# array([[1628, 2387, 4583]])

# %% [markdown]
# ##**Problem 3 :**
#
# ![Screenshot_23.png](data:image/png;base64,...)

# %% [markdown]
# ##**Solution 3 :**

# %%
print(A)
# Out:
# [[ 23  50  19]
#  [  7  12 109]
#  [ 57  67  98]]

# %% [markdown]
# Pertama yang ingin dilakukan adalah membuat Transpose pada matrik A kemudian dicari nilai determinan dan inversenya.

# %%
print('transpose:\n',A.T) #Transpose
# Out:
# transpose:
#  [[ 23   7  57]
#  [ 50  12  67]
#  [ 19 109  98]]

# %%
np.linalg.det(A.T) #Determinan
# Out:
# 131343.99999999997

# %%
np.linalg.inv(A.T) #Inverse
# Out:
# array([[-0.0466485 ,  0.04208034, -0.00163692],
#        [-0.02761451,  0.00891552,  0.0099662 ],
#        [ 0.03975819, -0.01807467, -0.00056341]])
